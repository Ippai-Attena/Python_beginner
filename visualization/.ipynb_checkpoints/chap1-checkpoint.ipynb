# %% [markdown]
# # プロットライブラリ（matplotlib）の使い方

# %% [markdown]
# プロットする段階では数値計算用のライブラリ（numpy）の使い方を知っているのが普通なので、まず簡単にパッケージ（ライブラリやモジュールともいう）について簡単に紹介。

# %% [markdown]
# Pythonはプログラミング言語。パソコン関連の事はやろうと思えば何でもできます。データ分析をするための道具というわけではありません。
#
# ロボットを動かしたり、ウェブサイトを自動で読み込んだり更新したり、アプリを作ったり何でもできます。Pythonの特徴は、他のプログラミング言語と比べて簡単というところです。実験科学者とかPCが苦手な人でもとっつきやすくなっています。そのため、データ分析をするためのパッケージがたくさん開発されてきました。それらのパッケージはもともとPythonに組み込まれているものではないので、パッケージをインストールして、プログラム中で呼び出してやる必要があるということです。
#
# 初めに行った
#
# ```python
# conda install hogehoge
# ```
#
# というのはパッケージのインストールをしていたのでした。

# %% [markdown]
# ## パッケージの呼び出し方
# 例えばだけど

# %%
import numpy as np

# %% [markdown]
# とすれば numpy を npという名前で呼び出すという意味になります。npの部分はプログラム中で使う別名で、自分で好きな名前を付けたら良いです（numpyって毎回打つのは辛いよねってことだけです）。ただ、大体の場合は業界標準があるので真似したほうが絶対に良いです。
#
#
# 他にも一部の機能だけ呼び題したい場合は

# %%
from numpy import array

# %% [markdown]
# のように、numpyが持っているarrayという機能を呼び出すということになります。
# これも最後にas hogehogeとすれば別名を付けられます。
# というわけで、pythonに元々提供されていない機能を使うときにパッケージを呼び出すことが分かったと思うので、細かい使い方は置いといてグラフをプロットしてみます。

# %% [markdown]
# ---

# %% [markdown]
# # matplotlibでプロットしてみる

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline 
#これはグラフをここにデフォルト表示するためのコマンドです。おまじないだと思って書いといてください。わかんなくていいです。

# %%
x = np.linspace(0,4*np.pi,1000)   #0-4piまでを1000分割
y = np.sin(x)   #sin(x)を計算。（1000個の値が出てくる）
plt.plot(x,y)

# %%
x = np.linspace(0,4*np.pi,20)   #0-4piまでを20分割
y = np.sin(x)   #sin(x)を計算。（20個の値が出てくる）
plt.plot(x,y)

# %%
x = np.linspace(0,4*np.pi,1000)   #0-4piまでを1000分割
for i in range(10):   # 0-9まで順番に値を取り出しでiに代入
    y = np.sin(x-(np.pi/10)*i)
    plt.plot(x,y)

# %% [markdown]
# ## ちょっと補足

# %% [markdown]
# __「=」について__
# Pythonに限らず、プログラミングで「=」は等しいという意味ではなく、代入するという意味で使います。「==」で等しいという意味になります。条件判定のときとかに使います。

# %%
1 == 1
# Out:
# True

# %%
1 == 2
# Out:
# False

# %% [markdown]
# のように使用します。

# %% [markdown]
# __Q. np.sinとかplt.plotとかの「.」ってどんな意味？__
# 「.」は所属を表しています。np.sinはnpの中にあるsin関数って意味です。
# sinは元々pythonにありません（あるにはあるけど、mathを別途呼び出すのでやることは同じ）。
# なので、どこからどんな機能を呼び出すのか明確にしてコードを書く必要があります。

# %% [markdown]
# __Q. なんでそんな面倒な仕様になってるの?__
# プログラミング言語は「関数型言語」と「オブジェクト指向型言語」に大別されます。
# 関数型の代表例としてはC言語が、オブジェクト指向型の代表としてPythonがあげられます。
# 関数型言語では、何か入力を与えたら、なんか出力を吐き出す「処理（関数）」をコーディングしていきます。
#
# 一方で「オブジェクト指向型」は、データと関数をまとめた「オブジェクト」というものを考えます。
# 必ずしもデータと関数がセットになったものじゃなくてもいいんですが、とにかく何かモノ（実体）があって、そいつを弄繰り回すイメージです。
#
#
#
#
# たとえ話をすると...
# 関数型でいう関数とは入力に対して処理を行う処理部分のことで、日常生活で例えるなら「ハサミ」とか「ノリ」とか「ホチキス」といったものに相当します。切ったり、貼ったり、まとめたりするわけです。当然紙以外にこんなことはできないので、石や鉄を渡そうとすると「無理っす（ERROR）」となるわけです。
#
# オブジェクト指向型では、まず最初に「モノ（紙）」を考えます。この紙にどんな処理をするかを記述します。なので、まず紙があって、それを「投げる」といった処理は「そんな事できる方法（関数）がないよ！（ERROR）」となるわけです。
#
# で、「なんでそんな面倒な仕様になってるの?」に戻ると、先にモノがあればできることが限定されるので、難しいことを考える必要がないわけです。
# 「ハサミ、ノリ、ホチキスで何ができる？」って言われるより、「紙に対してできることは？」って言われた方ができることのイメージはしやすくないですか？？？だから、「.」を使って何に対する処理なのか所属を明らかにするんです。
#
#
# ...何となくはわかったかな？
# 「オブジェクト指向ってなんだよ！」ってなっている人は結構見かけるので、わからなくても問題はないです。
# 一言でまとめるなら「モノが先か、道具が先か」って感じでしょうか。

# %% [markdown]
# # 細かい計算は置いておいて...
# グラフを綺麗に整形する方法の紹介。

# %%
x = np.linspace(0,4*np.pi,100)   #0-4piまでを100分割
y = np.sin(x)   #sin(x)を計算。（100個の値が出てくる）
plt.plot(x,y)

# %% [markdown]
# このグラフをいじくり倒してみます。
# x, yは上記で計算したものを再利用できるので、以下では省略。

# %% [markdown]
# ### 線の太さを変える

# %%
plt.plot(x,y, lw=10)   # line widthの略

# %% [markdown]
# ### scatter plot（散布図）にしたい

# %%
plt.scatter(x,y)

# %% [markdown]
# ### 色を変えたい
# 参考url: https://pythondatascience.plavox.info/matplotlib/%E8%89%B2%E3%81%AE%E5%90%8D%E5%89%8D

# %%
plt.scatter(x,y, color="r")

# %% [markdown]
# ### 図をデカく！

# %%
plt.figure(figsize=(14,10))   #figsize=(横、縦)
plt.scatter(x,y, color="r")

# %% [markdown]
# ### マーカーのサイズを変える

# %%
plt.scatter(x,y, s=100) # sはサイズの略

# %% [markdown]
# ### マーカーのエッジの色を変える

# %%
plt.scatter(x,y, edgecolors="r") # sはサイズの略

# %% [markdown]
# ### マーカーを半透明に

# %%
a = 0.6 #0になるほど透明（0~1の値で指定）
plt.scatter(x,y, alpha=a)

# %% [markdown]
# ### 軸ラベルとタイトルを付けたい

# %%
plt.scatter(x,y)
plt.title("sine curve")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0,0.5,'y axis')

# %% [markdown]
# ### 凡例も入れたいんですけど？

# %%
plt.scatter(x,y)
plt.legend(["sine courve"])

# %% [markdown]
# ### 軸ラベルとタイトルのフォントサイズを変えたい

# %%
plt.scatter(x,y)
fs = 20  # font sizeを指定した
plt.title("sine curve", fontsize=fs)
plt.xlabel("x axis",  fontsize=fs)
plt.ylabel("y axis",  fontsize=fs)
# Out:
# Text(0,0.5,'y axis')

# %% [markdown]
# ### デフォルトのフォントサイズを変えたほうが楽？

# %%
fs = 20
plt.rc('font', size=20)   # matplotlibのデフォルト設定をいじる

plt.scatter(x,y)
fs = 20  # font sizeを指定した
plt.title("sine curve")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0,0.5,'y axis')

# %% [markdown]
# ### 軸の値までデカくしたくないんですけど！

# %%
plt.rc('font', size=10)  #説明のために、一旦元のサイズに戻してるだけです。

fs = 5
plt.rc('xtick', labelsize=fs)   # matplotlibのデフォルト設定をいじる（x軸）
plt.rc('ytick', labelsize=fs)   # matplotlibのデフォルト設定をいじる（y軸）


plt.scatter(x,y)
fs = 20  # font sizeを指定した
plt.title("sine curve")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0,0.5,'y axis')

# %% [markdown]
# ### ラベルとタイトルは大きく、数字も見える程度に大きく別々に指定したい！
# デフォルトのフォントサイズを決めたうえで、ラベルとタイトルは別々に指定したらいいじゃない

# %%
plt.rc('font', size=10)  #説明のために、一旦元のサイズに戻してるだけです。

fs = 14
plt.rc('xtick', labelsize=fs)   # matplotlibのデフォルト設定をいじる（x軸）
plt.rc('ytick', labelsize=fs)   # matplotlibのデフォルト設定をいじる（y軸）


plt.scatter(x,y)
fs = 20  # font sizeを指定した
plt.title("sine curve", fontsize=fs)
plt.xlabel("x axis", fontsize=fs)
plt.ylabel("y axis", fontsize=fs)
# Out:
# Text(0,0.5,'y axis')

# %% [markdown]
# ### 表示するx軸とy軸の範囲を指定したい

# %%
plt.scatter(x,y)
plt.xlim(1,8)   #x軸の1-8の範囲だけ表示
plt.ylim(0,1)   #y軸の0-1の範囲だけ表示
# Out:
# (0, 1)

# %% [markdown]
# ### 正方形にしたい

# %%
plt.scatter(x,y)
ax = plt.gca()  #現在アクティブなグラフのオブジェクト（実体）をとってくる。get current axisの略
xlim = ax.get_xlim()   #描画されているx軸の最小値と最大値
ylim = ax.get_ylim()   ##描画されているy軸の最小値と最大値

xrange = xlim[1]-xlim[0]   #xlim[0]はxlimに入っている0番目の値をとってこいって意味。
yrange = ylim[1]-ylim[0]


ax.set_aspect(xrange/yrange)   # xの範囲/yの範囲って渡す

# %% [markdown]
# ### ここまでのまとめ
# グラフを正方形にして見栄え良くしてみます

# %%
font = {"family": "serif"}   #ちゃっかりフォントの種類も変えた
plt.rc("font", **font)
plt.rc('xtick', labelsize=16)   # matplotlibのデフォルト設定をいじる（x軸）
plt.rc('ytick', labelsize=16)   # matplotlibのデフォルト設定をいじる（y軸）

plt.figure(figsize=(7,7))
plt.plot(x,y, color="k", lw=3, ls="--")   #ls: line styleの略"--"で破線になる。kは黒という意味。*kuroとは関係ないです。
plt.scatter(x,y, s=100, color="blue")
plt.legend(["sine curve"], fontsize=14)

fs = 20  # font sizeを指定した
plt.title("sine curve", fontsize=fs)
plt.xlabel("$x$ axis", fontsize=fs)
plt.ylabel("$y$ axis", fontsize=fs)



ax = plt.gca()  #現在アクティブなグラフのオブジェクト（実体）をとってくる。get current axisの略
xlim = ax.get_xlim()   #描画されているx軸の最小値と最大値
ylim = ax.get_ylim()   ##描画されているy軸の最小値と最大値
xrange = xlim[1]-xlim[0]   #xlim[0]はxlimに入っている0番目の値をとってこいって意味。
yrange = ylim[1]-ylim[0]
ax.set_aspect(xrange/yrange)   # xの範囲/yの範囲って渡す

# %% [markdown]
# # 一つのグラフを出すのにコードがこんな必要なのかって？
# グラフを大量に出すときに真価を発揮します。
# 以下は一例なので、教えてないこともガンガン使います。
# 便利だってことだけ感じてもらえれば良いです。

# %%
x = np.linspace(0,4*np.pi,1000)   #0-4piまでを1000分割
for i in range(10):   # 0-9まで順番に値を取り出しでiに代入
    y = np.sin(x-(np.pi/10)*i)
    plt.plot(x,y)

# %% [markdown]
# これを別々にプロットしたいなー

# %%
ys = np.array([np.sin(x-(np.pi/10)*i) for i in range(10)]).T
df = pd.DataFrame(ys)

figsize = (14,4)
df.plot(subplots=True, figsize=figsize, layout=(2,5), sharex=True, sharey=True, rot=0);
plt.tight_layout()

# %% [markdown]
# あら簡単。

# %% [markdown]
# ---
# 10次元のデータが1000個あるけどクラスタリングしたいなー

# %%
data = pd.DataFrame(np.random.rand(1000,10))
data
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.952299  0.743601  0.240590  0.833788  0.051120  0.887594  0.335772
# 1    0.633093  0.079392  0.870144  0.513536  0.838259  0.415605  0.698686
# 2    0.620355  0.151152  0.922854  0.729693  0.800127  0.141505  0.541943
# 3    0.118847  0.931067  0.090193  0.989611  0.552896  0.681439  0.434239
# 4    0.045014  0.845650  0.269737  0.792327  0.509794  0.456919  0.775916
# 5    0.303788  0.590018  0.979219  0.064273  0.934819  0.363268  0.087645
# 6    0.590833  0.220100  0.887048  0.332952  0.332992  0.872408  0.281271
# 7    0.096461  0.275856  0.280226  0.357774  0.095940  0.814700  0.938367
# 8    0.005909  0.396942  0.373773  0.477271  0.425979  0.140411  0.414446
# 9    0.361460  0.995672  0.259565  0.599187  0.963735  0.555329  0.155641
# 10   0.415175  0.017528  0.639593  0.694829  0.829155  0.710418  0.755626
# 11   0.147946  0.292455  0.149350  0.184708  0.812683  0.119467  0.059331
# 12   0.649959  0.804309  0.275727  0.276302  0.953619  0.607163  0.844886
# 13   0.549534  0.932089  0.798375  0.606096  0.869646  0.577726  0.919792
# 14   0.400183  0.546842  0.844396  0.790071  0.842754  0.830870  0.599377
# 15   0.259069  0.179369  0.029704  0.272727  0.257447  0.927174  0.346179
# 16   0.942856  0.337691  0.118150  0.898592  0.874407  0.233915  0.687927
# 17   0.781662  0.169494  0.277628  0.644492  0.183691  0.478668  0.437738
# 18   0.987282  0.397343  0.420930  0.989426  0.254875  0.562935  0.291575
# 19   0.050573  0.016218  0.757561  0.356284  0.798272  0.868838  0.465029
# 20   0.242240  0.511778  0.611651  0.755973  0.907597  0.543293  0.001961
# 21   0.064891  0.756393  0.298801  0.216164  0.661712  0.362616  0.689144
# 22   0.788004  0.169451  0.948175  0.273105  0.933679  0.371540  0.157529
# 23   0.393517  0.530754  0.178155  0.673943  0.860921  0.281198  0.612257
# 24   0.434309  0.269331  0.707434  0.821279  0.972370  0.586192  0.743548
# 25   0.770662  0.265224  0.122960  0.775712  0.404611  0.373800  0.724869
# 26   0.961733  0.100649  0.103388  0.031835  0.546018  0.970787  0.646936
# 27   0.823359  0.150040  0.195686  0.532940  0.481411  0.194569  0.363777
# 28   0.506194  0.780265  0.769985  0.790407  0.005881  0.068767  0.595978
# 29   0.941838  0.442121  0.138800  0.088083  0.131353  0.481775  0.166303
# ..        ...       ...       ...       ...       ...       ...       ...
# 970  0.472864  0.607770  0.421528  0.986276  0.004540  0.050974  0.445614
# 971  0.812944  0.698598  0.261743  0.761156  0.334144  0.756720  0.013251
# 972  0.842664  0.119086  0.368560  0.304196  0.402475  0.427360  0.959054
# 973  0.946759  0.399976  0.574604  0.030139  0.176436  0.496803  0.243479
# 974  0.029064  0.994323  0.319318  0.987696  0.851748  0.126390  0.002257
# 975  0.745478  0.935343  0.767820  0.999373  0.054134  0.187003  0.351419
# 976  0.489726  0.975034  0.601423  0.794085  0.398002  0.143801  0.376239
# 977  0.510754  0.287936  0.637148  0.148576  0.396186  0.538581  0.417959
# 978  0.558379  0.795727  0.377044  0.033809  0.589038  0.351376  0.134206
# 979  0.901213  0.108682  0.452047  0.124181  0.749845  0.528406  0.572429
# 980  0.793733  0.932225  0.363831  0.045340  0.083275  0.559722  0.939876
# 981  0.351620  0.111953  0.974403  0.345640  0.310990  0.938981  0.403831
# 982  0.310296  0.020280  0.220773  0.215894  0.758814  0.933919  0.712077
# 983  0.384577  0.289775  0.361598  0.985528  0.656046  0.464745  0.101921
# 984  0.383702  0.415324  0.075746  0.707609  0.112703  0.337294  0.030790
# 985  0.286932  0.901033  0.033242  0.173698  0.813543  0.888090  0.844031
# 986  0.705726  0.099560  0.806454  0.177856  0.360628  0.507988  0.331550
# 987  0.294075  0.644144  0.922029  0.721976  0.940630  0.605960  0.669618
# 988  0.297132  0.796069  0.153600  0.696110  0.366904  0.087106  0.123552
# 989  0.087910  0.208374  0.584676  0.383140  0.079280  0.645034  0.513238
# 990  0.651695  0.929966  0.112826  0.597414  0.628335  0.789846  0.764302
# 991  0.732175  0.038913  0.866133  0.965603  0.975779  0.705074  0.081995
# 992  0.090026  0.585365  0.884627  0.248965  0.131625  0.394955  0.473654
# 993  0.304226  0.464615  0.006922  0.564526  0.371041  0.711772  0.530918
# 994  0.038139  0.048327  0.025964  0.719563  0.515414  0.141556  0.838545
# 995  0.650205  0.682725  0.496478  0.859662  0.573064  0.504588  0.378154
# 996  0.919545  0.318715  0.344253  0.797993  0.773008  0.885695  0.991462
# 997  0.726997  0.835794  0.479105  0.077628  0.156385  0.373994  0.544017
# 998  0.638091  0.300150  0.398269  0.149904  0.268232  0.356760  0.404385
# 999  0.629825  0.127456  0.495408  0.905993  0.174428  0.865001  0.733034
#
#             7         8         9
# 0    0.025249  0.626910  0.927383
# 1    0.264371  0.101057  0.393643
# 2    0.618829  0.092186  0.204136
# 3    0.582676  0.203457  0.399970
# 4    0.312446  0.880214  0.586256
# 5    0.091234  0.873491  0.900741
# 6    0.604745  0.833844  0.875901
# 7    0.051070  0.255840  0.250746
# 8    0.029011  0.927027  0.505661
# 9    0.316126  0.339078  0.156633
# 10   0.268147  0.754132  0.532134
# 11   0.770169  0.619909  0.439046
# 12   0.380776  0.261389  0.936421
# 13   0.441200  0.301891  0.832036
# 14   0.518501  0.946647  0.471207
# 15   0.547084  0.807752  0.989910
# 16   0.664666  0.344804  0.218309
# 17   0.102845  0.701904  0.623214
# 18   0.197096  0.334612  0.817504
# 19   0.813289  0.233637  0.334646
# 20   0.703647  0.303318  0.021596
# 21   0.671215  0.367164  0.763284
# 22   0.526525  0.026519  0.191302
# 23   0.692701  0.915264  0.788437
# 24   0.659845  0.394029  0.593306
# 25   0.668440  0.572012  0.285613
# 26   0.390281  0.015508  0.779011
# 27   0.346813  0.888687  0.739489
# 28   0.077156  0.140836  0.327395
# 29   0.940678  0.774969  0.596788
# ..        ...       ...       ...
# 970  0.004727  0.410319  0.139784
# 971  0.620197  0.269671  0.495495
# 972  0.748994  0.795177  0.471907
# 973  0.120677  0.511651  0.222101
# 974  0.419021  0.944101  0.115815
# 975  0.607294  0.234247  0.166569
# 976  0.100759  0.058947  0.368708
# 977  0.719454  0.923037  0.250142
# 978  0.615756  0.414071  0.854805
# 979  0.083241  0.022671  0.542733
# 980  0.562386  0.107430  0.534593
# 981  0.622693  0.755003  0.005686
# 982  0.516316  0.267230  0.646832
# 983  0.683024  0.459929  0.505508
# 984  0.750332  0.516136  0.642137
# 985  0.135502  0.507956  0.478161
# 986  0.161169  0.064630  0.308441
# 987  0.017369  0.904101  0.759005
# 988  0.814314  0.893861  0.649210
# 989  0.490852  0.204541  0.655713
# 990  0.371835  0.115132  0.417058
# 991  0.101344  0.841729  0.450980
# 992  0.563756  0.734648  0.102834
# 993  0.122914  0.319033  0.274746
# 994  0.963309  0.083248  0.705817
# 995  0.799957  0.781885  0.642250
# 996  0.468486  0.504903  0.191424
# 997  0.100655  0.227552  0.461943
# 998  0.097974  0.449724  0.225938
# 999  0.114047  0.752573  0.609292
#
# [1000 rows x 10 columns]

# %%
import seaborn as sns
sns.clustermap(data)

# %% [markdown]
# え？（importを除けば）1行で終わり？？

# %% [markdown]
# # メッチャ便利！
